# %% [markdown]
# # Nama: Taqiyuddin Ja'far
# ## NIM: 250401020186
# ### Kelas: IF405

# %%
#SEL 1: Output Sederhana
print("Hello, Data Science!")
# Out:
# Hello, Data Science!

# %%
#SEL 2: Variabel & tipe data
nama     = "Taqiyuddin Ja'far"
angkatan = 2026
aktif = True
print(f"Halo, nama saya {nama} angkatan {angkatan}")
print(f"Aktif : {aktif}")
# Out:
# Halo, nama saya Taqiyuddin Ja'far angkatan 2026
# Aktif : True

# %%
#SEL 3: List & perulangan
tools = ["Python","Jupyter","Numpy","Colab","Github"]
for i, tool in enumerate(tools, start=1):
    print(f"{i}. {tool}")
# Out:
# 1. Python
# 2. Jupyter
# 3. Numpy
# 4. Colab
# 5. Github

# %%
#SEL 4: Fungsi python
#Sel 4: Fungsi
def perkenalan(nama, prodi, angkatan):
  return f"{nama} | {prodi} | {angkatan}"

print(perkenalan("Taqiyuddin Ja'far", "Informatika", 2026))
# Out:
# Taqiyuddin Ja'far | Informatika | 2026

# %% [markdown]
# # Kesimpulan
#
# **Apa yang dipelajari:**
# Dalam sesi ini, saya telah mempelajari dasar-dasar pemrograman Python di lingkungan Google Colab, mulai dari pencetakan output sederhana, manipulasi variabel, penggunaan tipe data dasar (string, integer, boolean), hingga pengelolaan struktur data `list` dan pembuatan fungsi.
#
# **Temuan Utama:**
# - Python memudahkan pengelolaan data kolektif menggunakan `list` dan iterasi dengan `enumerate`.
# - Penggunaan f-string sangat efisien untuk memformat output string yang melibatkan variabel.
# - Modularitas kode dapat ditingkatkan melalui pendefinisian fungsi.
#
# **Keterbatasan atau Pertanyaan:**
# - Saat ini eksplorasi masih terbatas pada struktur data bawaan Python. Muncul pertanyaan mengenai bagaimana cara menangani data yang lebih kompleks dengan Python.
